# %%
# [Exercise 02-1]
# a. 새로운 노트북 Excersice02.1.ipynb 만들기
from random import*
import numpy as np
import pandas as pd
import csv

# Google Drive mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# b. 랜덤 넘버가 채워지는 10개 column을 가지는 20개 data 를 만들어 이를 mydf.csv라는 file로 저장하세요.

# 20x10 Random number data 생성
df = pd.DataFrame(np.random.randn(20,10))

# mydf.csv 저장
df.to_csv("../content/drive/My Drive/Colab Notebooks/mydf.csv", header=True)

# %%
# c. mydf.csv 파일을 다시 읽어 보세요.
data = pd.read_csv("../content/drive/My Drive/Colab Notebooks/mydf.csv", index_col=0)
data
# Out:
#            0         1         2  ...         7         8         9
# 0   0.176296  0.053585  0.461583  ... -1.622712  0.511287  0.799161
# 1   0.258055 -0.712985 -1.278741  ... -1.427193  0.248888  0.864604
# 2   0.469908 -0.501889 -0.102699  ... -0.072030 -0.297563  0.434448
# 3  -1.302378  1.414479  0.846367  ... -0.134823  0.288448 -0.142412
# 4  -1.771913  0.324318 -0.822122  ...  0.063810 -0.982451 -0.870360
# 5   0.087214 -0.738661 -0.168725  ...  0.183767  0.590819 -1.682518
# 6   0.315665  0.298484 -0.996705  ... -0.406414 -1.014710 -0.214009
# 7   0.809544 -0.816547 -0.031745  ...  1.966145 -1.883264  0.378780
# 8   0.023730 -0.738497 -0.426018  ...  1.185943 -0.044511 -0.880361
# 9   1.236821 -1.433878 -0.142152  ... -0.362547 -0.139930 -0.607066
# 10  0.417670  0.540514 -0.990679  ... -0.721549  2.086662  0.487810
# 11 -1.649070  1.406340 -0.291630  ...  0.924746  1.823951 -1.651400
# 12  1.749339 -1.161201  0.763670  ... -1.084702 -1.329648  0.550055
# ...
